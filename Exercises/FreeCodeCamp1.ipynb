# %% [markdown]
# <a href="https://colab.research.google.com/github/Ian-Siegert/Learning-Python/blob/main/Exercises/FreeCodeCamp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os as os

# %matplotlib inline

# %cd /content/drive/MyDrive/Learning Python
os.getcwd()

# !head Data/sales_data.csv

sales = pd.read_csv(
    "Data/sales_data.csv",
    parse_dates = ['Date'])

sales.head()
sales.info()
sales.describe()

sales['Unit_Cost'].describe()

sales['Unit_Cost'].mean()
sales['Unit_Cost'].median()

sales['Unit_Cost'].plot(kind = 'box', vert = False, figsize = [14,6])
# Out:
# <Axes: >
